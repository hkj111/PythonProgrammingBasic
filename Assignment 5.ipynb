# %% [markdown]
# # Assignment 5
# ## Harsh Kumar Jangir
# ## harshkumarjangir2014@gmail.com
# ## 26-03-2021

# %% [markdown]
# ### 1. Write a Python Program to Find LCM?

# %%
n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))
gcd=0
n=max(abs(n1),abs(n2))
for i in range(1,n+1):
    if n1%i==0 and n2%i==0:
        gcd=i
lcm = (n1*n2)/gcd

print("Lcm of {} and {} is {}".format(str(n1),str(n2),str(lcm)))
# Out:
# Enter first number: 14
# Enter second number: 12
# Lcm of 14 and 12 is 84.0

# %% [markdown]
# ### 2. Write a Python Program to Find HCF?

# %%
n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))
gcd=0
n=max(abs(n1),abs(n2))

for i in range(1,n+1):
    if n1%i==0 and n2%i==0:
        gcd=i


print("HCF of {} and {} is {}".format(str(n1),str(n2),str(gcd)))
# Out:
# Enter first number: 14
# Enter second number: 12
# HCF of 14 and 12 is 2

# %% [markdown]
# ### 3. Write a Python Program to Convert Decimal to Binary, Octal and Hexadecimal?

# %%
#For decimal to binary

n1= input("Enter the decimal number ")

if '.' not in n1:
    dec=[]
    n=int(n1)
    dum=n
    decimal=0
    binarynumber=0.0

    f=[]
    fr=0
    if n!=0:
        for i in range(1,dum+1):
            dec.append(str(n%2))
            n=n//2
        dec.reverse()

        ind=dec.index('1')
        decimal = int(''.join(dec[ind:]))
    else:
        decimal=0
        

else:
    list1 =n1.split('.')
    dec=[]
    n=int(list1[0])
    fraction=float('.'+list1[1])
    dum=n
    decimal=0
    binarynumber=0.0

    f=[]
    fr=0
    if n!=0:
        for i in range(1,dum+1):
            dec.append(str(n%2))
            n=n//2
        dec.reverse()

        ind=dec.index('1')
        decimal = int(''.join(dec[ind:]))
    else:
        decimal=0
    
    while fraction!=0.0:
#     print("Starting loop ",fraction)
        if fraction==0.0:
            break
        elif fraction*2 >= 1:
            fraction=fraction*2-1
            f.append('1')
            continue
        elif fraction*2<1:
#         print("in the elif",fraction)
            f.append('0')
            fraction=fraction*2
    fr = ''.join(f)



binarynumber = float(str(decimal)+'.'+str(fr))
print("Binary number = ",binarynumber)

# For decimal to Octal


if '.' not in n1:
    dec=[]
    n=int(n1)
    dum=n
    decimal=0
    binarynumber=0.0

    f=[]
    fr=0
    if n!=0:
        for i in range(1,dum+1):
            dec.append(str(n%8))
            n=n//8
        dec.reverse()

        for i in dec:
            if int(i)>0:
                ind=dec.index(i)
                break
        decimal = int(''.join(dec[ind:]))
    else:
        decimal=0
        

else:
    list1 =n1.split('.')
    dec=[]
    n=int(list1[0])
    fraction=float('.'+list1[1])
    dum=n
    decimal=0
    binarynumber=0.0

    f=[]
    fr=0
    if n!=0:
        for i in range(1,dum+1):
            dec.append(str(n%8))
            n=n//8
        dec.reverse()

        for i in dec:
            if int(i)>0:
                ind=dec.index(i)
                break
        decimal = int(''.join(dec[ind:]))
    else:
        decimal=0
    
    for i in range(0,10):
        fraction=fraction*8
        s=str(fraction)
#     print(s)
        s=list(s)
#     print(s)
        f.append(s[0])
#     print(f)
        s[0]='0'
#     print(s)
        s=''.join(s)
#     print(s)
        fraction=float(s)
        if fraction==0.0:
            break
    
    fr = ''.join(f)



binarynumber = float(str(decimal)+'.'+str(fr))
print("Octal number= ",binarynumber)
        
#Decimal to fraction
if '.' not in n1:
    dec=[]
    n=int(n1)
    dum=n
    decimal=[]
    binarynumber=0.0
    hexadec=''

    f=[]
    fr=0
    if n!=0:
        for i in range(1,dum+1):
            dec.append(str(n%16))
            n=n//16
        dec.reverse()

        for i in dec:
            if int(i)>0:
                ind=dec.index(i)
                break
        
        decimal = dec[ind:]
        for i in range(0,len(decimal)):
            h=decimal[i]
            if h=='10':
                decimal[i]='A'
            elif h=='11':
                decimal[i]='B'
            elif h=='12':
                decimal[i]='C'
            elif h=='13':
                decimal[i]='D'
            elif h=='14':
                decimal[i]='E'
            elif h=='15':
                decimal[i]='F'
        hexadec=''.join(decimal)
    else:
        hexadec='0'
        

else:
    list1 =n1.split('.')
    dec=[]
    n=int(list1[0])
    fraction=float('.'+list1[1])
    dum=n
    decimal=[]
    binarynumber=0.0
    hexadec=''

    f=[]
    fr=''
    if n!=0:
        for i in range(1,dum+1):
            dec.append(str(n%16))
            n=n//16
        dec.reverse()

        for i in dec:
            if int(i)>0:
                ind=dec.index(i)
                break
        
        decimal = dec[ind:]
        for i in range(0,len(decimal)):
            h=decimal[i]
            if h=='10':
                decimal[i]='A'
            elif h=='11':
                decimal[i]='B'
            elif h=='12':
                decimal[i]='C'
            elif h=='13':
                decimal[i]='D'
            elif h=='14':
                decimal[i]='E'
            elif h=='15':
                decimal[i]='F'
        hexadec=''.join(decimal)
    else:
        hexadec='0'
    
    for i in range(0,10):
        fraction=fraction*16
        s=str(fraction)
#     print(s)
        s=list(s)
#     print(s)
        index=s.index('.')
        slic=s[:index]
        a=''.join(slic)
        f.append(a)
#     print(f)
        for i in range(0,index):
            s[i]='0'
#     print(s)
        s=''.join(s)
#     print(s)
        fraction=float(s)
        if fraction==0.0:
            break
    for i in range(0,len(f)):
            h=f[i]
            if h=="10":
                f[i]='A'
            elif h=='11':
                f[i]='B'
            elif h=='12':
                f[i]='C'
            elif h=='13':
                f[i]='D'
            elif h=='14':
                f[i]='E'
            elif h=='15':
                f[i]='F'
    
fr = ''.join(f)


if fr=='':
    fr='0'
binarynumber = hexadec+'.'+fr
print("Hexadecimal number = ",binarynumber)
# Out:
# Enter the decimal number 12.1234
# Binary number =  1100.000111111001
# Octal number=  14.0771344435
# Hexadecimal number =  C.1F97247453

# %% [markdown]
# ### 4. Write a Python Program To Find ASCII value of a character?

# %%
choice='y'
while choice=='y':
    c = input("Enter a character: ")
    if len(c)>1:
        print("Enter only 1 character")
        choice=input("Do you want to try again? Y or N ")
        choice=choice.lower()
    else:
        print("Ascii value of {} is {}".format(c,str(ord(c))))
        choice=input("Do you want to try again? Y or N ")
        choice=choice.lower()
# Out:
# Enter a character: 4
# Ascii value of 4 is 52
# Do you want to try again? Y or N y
# Enter a character: b
# Ascii value of b is 98
# Do you want to try again? Y or N n

# %% [markdown]
# ### 5. Write a Python Program to Make a Simple Calculator with 4 basic mathematical operations?

# %%
exp = input("Enter your expression \nFor example 3+4/4 like this \n")
print(eval(exp))
# Out:
# Enter your expression
# For example 3+4/4 like this
# 3+4
# 7
